# %% [markdown]
# # Regression Tree from job search data
# import, explore and prepare data
# build a Regression Tree model
# visualize the structure of a Regression Tree
# Prune a Regression Tree

# %% [markdown]
# ## 1. Getting the Data

# %%
import pandas as pd
tyonhakuexcel1 = pd.read_csv('tyonhakuexcel2.csv')
tyonhakuexcel1.head()
# Out:
#    Company      Job title     Applied Applied date   Rejection Rejection date  \
# 0        1  Data engineer  1750712400    24.6.2025  1751230800      30.6.2025
# 1        2  Data engineer  1754859600    11.8.2025  1756155600      26.8.2025
# 2        3  Data engineer  1755032400    13.8.2025  1756760400       2.9.2025
# 3        4  Data engineer  1755464400    18.8.2025  1755637200      20.8.2025
# 4        5   Data Analyst  1755464400    18.8.2025  1757365200       9.9.2025
#
#    interview     Status  Interview status  Location
# 0        NaN  rejection             False  Helsinki
# 1        NaN  rejection             False  Helsinki
# 2        NaN  rejection             False  Helsinki
# 3        NaN  rejection             False  Helsinki
# 4        NaN  rejection             False  Helsinki

# %% [markdown]
# ## 2. Investigating Data

# %%
tyonhakuexcel1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           10 non-null     int64
#  1   Job title         10 non-null     object
#  2   Applied           10 non-null     int64
#  3   Applied date      10 non-null     object
#  4   Rejection         10 non-null     int64
#  5   Rejection date    10 non-null     object
#  6   interview         0 non-null      float64
#  7   Status            10 non-null     object
#  8   Interview status  10 non-null     bool
#  9   Location          10 non-null     object
# dtypes: bool(1), float64(1), int64(3), object(5)
# memory usage: 862.0+ bytes

# %%
#Trying to keep the "date" data as int64
tyonhakuexcel1['Applied'] = tyonhakuexcel1['Applied'].astype('int64')
#The date does not print in right format.
tyonhakuexcel1.describe()
# Out:
#         Company       Applied     Rejection  interview
# count  10.00000  1.000000e+01  1.000000e+01        0.0
# mean    5.50000  1.755032e+09  1.756130e+09        NaN
# std     3.02765  1.580068e+06  1.842772e+06        NaN
# min     1.00000  1.750712e+09  1.751231e+09        NaN
# 25%     3.25000  1.755140e+09  1.756091e+09        NaN
# 50%     5.50000  1.755464e+09  1.756501e+09        NaN
# 75%     7.75000  1.755529e+09  1.757214e+09        NaN
# max    10.00000  1.756501e+09  1.757624e+09        NaN

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#Job titles and rejection days
ax = sns.scatterplot(data = tyonhakuexcel1, 
                     x = 'Job title', 
                     y = 'Rejection', 
                     hue = 'Status', 
                     style = 'Status', 
                     s = 50)
ax = plt.legend(bbox_to_anchor = (1.02, 1), loc = 'upper left')

# %%
#Day of sending application vs rejeciton date
ax = sns.scatterplot(data = tyonhakuexcel1, 
                     x = 'Applied', 
                     y = 'Rejection', 
                     hue = 'Status', 
                     style = 'Status', 
                     s = 150)
ax = plt.legend(bbox_to_anchor = (1.02, 1), loc = 'upper left')
